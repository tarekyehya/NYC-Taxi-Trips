# %%
# dir
raw_path = "../data/raw/yellow_tripdata_2020-01.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
raw_data = pd.read_csv(raw_path)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
raw_data.shape
# Out:
# (6405008, 18)

# %%
raw_sample = raw_data.sample(n=1000000)

# %%
raw_sample.head()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 5660303       2.0  2020-01-29 07:55:38   2020-01-29 08:04:47              1.0
# 2043884       1.0  2020-01-11 18:31:38   2020-01-11 18:41:03              1.0
# 3475701       1.0  2020-01-18 12:16:40   2020-01-18 12:19:04              2.0
# 4290383       1.0  2020-01-22 18:09:10   2020-01-22 18:11:59              1.0
# 6092308       2.0  2020-01-30 22:57:18   2020-01-30 23:16:25              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 5660303           3.21         1.0                  N           238
# 2043884           1.20         1.0                  N           249
# 3475701           0.50         1.0                  N           262
# 4290383           0.50         1.0                  N           239
# 6092308           9.93         1.0                  N           132
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
raw_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 5660303 to 1926531
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               989825 non-null   float64
#  1   tpep_pickup_datetime   1000000 non-null  object
#  2   tpep_dropoff_datetime  1000000 non-null  object
#  3   passenger_count        989825 non-null   float64
#  4   trip_distance          1000000 non-null  float64
#  5   RatecodeID             989825 non-null   float64
#  6   store_and_fwd_flag     989825 non-null   object
#  7   PULocationID           1000000 non-null  int64
#  8   DOLocationID           1000000 non-null  int64
#  9   payment_type           989825 non-null   float64
#  10  fare_amount            1000000 non-null  float64
#  11  extra                  1000000 non-null  float64
#  12  mta_tax                1000000 non-null  float64
# ...

# %% [markdown]
# > datatime is an object data type >> date

# %% [markdown]
# > store_and_fwd_flag >> category

# %%
raw_sample.sample(2)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 6034598       2.0  2020-01-30 19:52:45   2020-01-30 20:08:09              1.0
# 5306964       2.0  2020-01-27 12:20:02   2020-01-27 12:30:38              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 6034598           0.72         1.0                  N           138
# 5306964           0.75         1.0                  N           161
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 6034598           138           2.0         10.5    1.0      0.5         0.0
# 5306964           230           2.0          8.0    0.0      0.5         0.0
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 6034598           0.0                    0.3          12.3
# 5306964           0.0                    0.3          11.3
#
#          congestion_surcharge
# 6034598                   0.0
# 5306964                   2.5

# %%
raw_sample.isnull().sum()
# Out:
# VendorID                 10175
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          10175
# trip_distance                0
# RatecodeID               10175
# store_and_fwd_flag       10175
# PULocationID                 0
# DOLocationID                 0
# payment_type             10175
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         0
# dtype: int64

# %% [markdown]
# > 65 from 6000,000 we can drob them

# %%
raw_sample.describe()
# Out:
#             VendorID  passenger_count   trip_distance     RatecodeID  \
# count  989825.000000     989825.00000  1000000.000000  989825.000000
# mean        1.670028          1.51337        2.902215       1.060307
# std         0.470203          1.14924        3.828611       0.820113
# min         1.000000          0.00000      -30.620000       1.000000
# 25%         1.000000          1.00000        0.960000       1.000000
# 50%         2.000000          1.00000        1.600000       1.000000
# 75%         2.000000          2.00000        2.940000       1.000000
# max         2.000000          9.00000       98.390000      99.000000
#
#          PULocationID    DOLocationID   payment_type     fare_amount  \
# count  1000000.000000  1000000.000000  989825.000000  1000000.000000
# mean       164.704399      162.791460       1.269142       12.709151
# std         65.511208       69.932407       0.473238       12.077646
# ...

# %% [markdown]
# > the min of trip_distance is minus

# %%
raw_sample.passenger_count.unique()
# Out:
# array([ 1.,  2.,  0.,  3., nan,  4.,  6.,  5.,  7.,  8.,  9.])
